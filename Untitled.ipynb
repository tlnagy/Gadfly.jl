# %%
using Gadfly
# Out:
# WARNING: New definition
#     +(AbstractArray, DataArrays.DataArray) at /Users/tamasnagy/.julia/v0.4/DataArrays/src/operators.jl:276
# is ambiguous with:
#     +(WoodburyMatrices.SymWoodbury, AbstractArray{T<:Any, 2}) at /Users/tamasnagy/.julia/v0.4/WoodburyMatrices/src/SymWoodburyMatrices.jl:107.
# To fix, define
#     +(WoodburyMatrices.SymWoodbury, DataArrays.DataArray{T<:Any, 2})
# before the new definition.
# WARNING: New definition
#     +(AbstractArray, DataArrays.AbstractDataArray) at /Users/tamasnagy/.julia/v0.4/DataArrays/src/operators.jl:300
# is ambiguous with:
#     +(WoodburyMatrices.SymWoodbury, AbstractArray{T<:Any, 2}) at /Users/tamasnagy/.julia/v0.4/WoodburyMatrices/src/SymWoodburyMatrices.jl:107.
# To fix, define
#     +(WoodburyMatrices.SymWoodbury, DataArrays.AbstractDataArray{T<:Any, 2})
# before the new definition.

# %%
x, y = rand(1000), rand(1000);

# %%
plot(x=x, y=y, Geom.path)
# Out:
# Plot(...)

# %%
Profile.clear()

# %%
@profile plot(x=x, y=y, Geom.path)
# Out:
# Plot(...)

# %%
using ProfileView
# Out:
# LoadError: ArgumentError: ProfileView not found in path
# while loading In[5], in expression starting on line 1
#
#  in require at /usr/local/Cellar/julia/0.4.6_1/lib/julia/sys.dylib

# %%
ProfileView.view()
# Out:
# ProfileView.ProfileData(ColorTypes.RGB{FixedPointNumbers.UFixed{UInt8,8}}[RGB{U8}(0.91,0.439,0.867) RGB{U8}(1.0,0.643,0.612) RGB{U8}(0.91,0.439,0.867) RGB{U8}(1.0,0.643,0.612) RGB{U8}(0.91,0.439,0.867) RGB{U8}(1.0,0.643,0.612) RGB{U8}(0.91,0.439,0.867) RGB{U8}(1.0,0.643,0.612) RGB{U8}(0.91,0.439,0.867) RGB{U8}(1.0,0.643,0.612) RGB{U8}(0.91,0.439,0.867) RGB{U8}(1.0,0.643,0.612)],Dict(0x000000031e2a3393=>StackFrame[ in ip:0x31e2a3392],0x000000031e2d02c4=>StackFrame[ in apply_scale(::Gadfly.Scale.ContinuousScale, ::Array{Gadfly.Aesthetics,1}, ::Gadfly.Data, ::Vararg{Gadfly.Data,N}) at scale.jl:246],0x000000031e2cad4e=>StackFrame[ in apply_scales(::Iterators.Distinct{Base.ValueIterator{Dict{Symbol,Gadfly.ScaleElement}}}, ::Array{Gadfly.Aesthetics,1}, ::Gadfly.Data, ::Vararg{Gadfly.Data,N}) at scale.jl:39],0x000000031e2ae9f9=>StackFrame[ in render(::Gadfly.Plot) at Gadfly.jl:799],0x000000031e2838e7=>StackFrame[ in ip:0x31e2838e6],0x000000031e2c9afb=>StackFrame[ in apply_scales(::Iterators
# ...

# %%
Pkg.add("ProfileView")
# Out:
# WARNING: julia is fixed at 0.4.6 conflicting with requirement for Combinatorics: [0.5.0-,∞)
# INFO: Installing Docile v0.5.23
# INFO: Installing Gtk v0.10.2
# INFO: Installing GtkUtilities v0.1.0
# INFO: Installing ProfileView v0.1.3
# INFO: Building Homebrew
# Updated Homebrew from 5d603c3 to c39f0ba.
# Updated 1 tap (homebrew/core).
# ==> New Formulae
# direvent
# feedgnuplot
# fsevents-tools
# hg-fast-export
# hopenpgp-tools
# libdivecomputer
# pybind11
# vaulted
# ==> Updated Formulae
# afflib
# afl-fuzz
# amazon-ecs-cli
# android-ndk
# antigen
# app-engine-go-32
# app-engine-java
# app-engine-python
# apr-util
# arangodb
# argon2
# aria2
# aws-sdk-cpp
# awscli
# b2-tools
# bash-preexec
# brew-gem
# caddy
# charm
# convox
# coturn
# davix
# deis
# deisctl
# diff-pdf
# docker-machine
# emp
# etcd
# exploitdb
# fabio
# ffmpegthumbnailer
# fftw
# flatcc
# flow
# fontconfig
# fswatch
# fzf
# gcc
# git-flow-avh
# git-lfs
# giter8
# glide
# gnatsd
# grib-api
# gssh
# ...
